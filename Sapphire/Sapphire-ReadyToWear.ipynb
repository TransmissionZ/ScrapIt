# %%
#libraries:

from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq
import urllib.request
import pandas as pd

# %%
#Initialising Lists
all_links = []
all_pages = []

# %%
#Scraping Pages
link = 'https://pk.sapphireonline.pk/collections/ready-to-wear'
all_pages.append(link)
base_link = 'https://pk.sapphireonline.pk'
while (True):
        uClient = uReq(link)
        all_web = uClient.read()
        uClient.close()
        page_soup = soup(all_web, "html.parser")
        pages = page_soup.find('div', {'class':'infinite-scrolling'})
        if (pages == None):
            break
        link = base_link + pages.a['href']
        all_pages.append(link)

print("All links Fetched")
# Out:
# All links Fetched

# %%
all_pages
# Out:
# ['https://pk.sapphireonline.pk/collections/ready-to-wear',
#  'https://pk.sapphireonline.pk/collections/ready-to-wear?page=2',
#  'https://pk.sapphireonline.pk/collections/ready-to-wear?page=3',
#  'https://pk.sapphireonline.pk/collections/ready-to-wear?page=4',
#  'https://pk.sapphireonline.pk/collections/ready-to-wear?page=5',
#  'https://pk.sapphireonline.pk/collections/ready-to-wear?page=6',
#  'https://pk.sapphireonline.pk/collections/ready-to-wear?page=7',
#  'https://pk.sapphireonline.pk/collections/ready-to-wear?page=8']

# %%
#Scraping All Product Links
product_container = []
for link in all_pages:
    uClient = uReq(link)
    all_web = uClient.read()
    uClient.close()
    page_soup = soup(all_web, "html.parser")
    for product in page_soup.findAll("div", {"class":"grid-item col-6 col-md-4 col-xl-3 four-columns"}):
        product_container.append(product)
    #Retrieving All Product Links
    for link in range(len(product_container)):
        x = base_link + product_container[link].a['href']
        all_links.append(x)

# %%
all_rows = []
len(all_links)
# Out:
# 1702

# %%
# %%time
#Scraping 1 product
#print(all_links[1])
link = 'https://pk.sapphireonline.pk/collections/ready-to-wear/products/azure'
uClient = uReq(link)
all_web = uClient.read()
uClient.close()
name = None
des1 = None
des2 = None
detail = None
color = None
fabric = None
oldprice = None
newprice = None
all_sizes = None
extra_detail = None
extra_detail2 = None
product_soup = soup(all_web, "html.parser")
name = product_soup.find("h2", {"itemprop":"name"}).text.strip()
content = product_soup.find("section", {"id":'content1'})('p')
name = product_soup.find("h2", {"itemprop":"name"}).text.strip()
if (len(content) != 1 and len(content) <= 5):
    if (content[1].text != 'Ready To Wear'):
        if (content[0].strong != None):
            des1 = content[0].strong.text
        else:
            b = content[0].text.find("\n")
            des1 = content[0].text[:b].strip()

        des2 = content[0].text.replace(des1, "").strip()
        details = content[1].text
        z = details.find("Color")
        detail = details[8:z].strip()
        l = details.find("Fabric")
        color = details[z+6:l].strip()
        fabric = details[l+7:].strip()
        if len(content) == 3:
            extra_detail = content[2].text
    else:
        des1 = content[2].text.strip()
        des2 = content[0].text.strip()
        detail = content[1].text.strip()
        z = content[3].text.find("Fabric")
        color = content[3].text[:z].replace("Color:", "").strip()
        fabric = content[3].text[z:].replace("Fabric:", "").strip()
elif (len(content) >= 6):
    des1 = content[3].text.strip()
    des2 = content[1].text.strip()
    detail = content[4].text.strip()
    z = content[5].text.find("Fabric")
    color = content[5].text[:z].replace("Color:", "").strip()
    fabric = content[5].text[z:].replace("Fabric:", "").strip()
    
else:
    content = content[0]
    des1 = content.strong.text.strip()
    content = content.text
    z = content.find("Details:")
    l = content.find("Color")
    k = content.find("Fabric")
    j = content.find("SIZE")
    des2 = content[len(des1):z].strip()
    detail = content[z:l].replace("Details:", "").strip()
    color = content[l:k].replace("Color:", "").strip()
    fabric = content[k:j].replace("Fabric:", "").strip()
    
    
prices = product_soup.find("div",{"class":"prices"})('span')
oldprice = prices[1].text.strip()
newprice = prices[2].text.strip()
sizes = product_soup.find_all("div", {'class':'swatch-element'})
all_sizes = []
for size in sizes:
    all_sizes.append(size.label.text.strip())
    
all_sizes = ','.join(all_sizes)
    
row = {'Name':name,'Detail':detail,'Main-Description': des1,'Sub-Description':des2, 'Old-Price': oldprice, 'New-Price': newprice,'Color': color, 'Fabric' : fabric, 'All Sizes' : all_sizes,"Extra Detail-1" : extra_detail, "Extra Detail-2": extra_detail2}

print(name, des1, des2,detail,color,fabric, oldprice, newprice, all_sizes)
# Out:
# Azure Kaftan The loose, stylish denim shirt with the stylish collar pairs perfect with simple white pants for a modern, well tailored ensemble. Plain Front Panel
# Plain Back Panel
# Collar with Buttons
# Three Quarter Sleeves Blue Denim Rs.2,650.00 Rs.1,325.00 XXS,XS,S,M,L,XL
# Wall time: 1.62 s

# %%
# %%time
#Scraping All Products
#Scraping 1 product
#print(all_links[1])


h = 0
x = 0
faultylinks = []
for link in all_links:
    h += 1
    if (h%10 == 0):    
        print('working...')
    
    try:
        uClient = uReq(link)
        all_web = uClient.read()
        uClient.close()
        name = None
        des1 = None
        des2 = None
        detail = None
        color = None
        fabric = None
        oldprice = None
        newprice = None
        all_sizes = None
        extra_detail = None
        product_soup = soup(all_web, "html.parser")
        name = product_soup.find("h2", {"itemprop":"name"}).text.strip()
        content = product_soup.find("section", {"id":'content1'})('p')
        name = product_soup.find("h2", {"itemprop":"name"}).text.strip()
        if (len(content) != 1 and len(content) <= 5):
            if (content[1].text != 'Ready To Wear'):
                if (content[0].strong != None):
                    des1 = content[0].strong.text
                else:
                    b = content[0].text.find("\n")
                    des1 = content[0].text[:b].strip()

                des2 = content[0].text.replace(des1, "").strip()
                details = content[1].text
                z = details.find("Color")
                detail = details[8:z].strip()
                l = details.find("Fabric")
                color = details[z+6:l].strip()
                fabric = details[l+7:].strip()
                if len(content) == 3:
                    extra_detail = content[2].text
            else:
                des1 = content[2].text.strip()
                des2 = content[0].text.strip()
                detail = content[1].text.strip()
                z = content[3].text.find("Fabric")
                color = content[3].text[:z].replace("Color:", "").strip()
                fabric = content[3].text[z:].replace("Fabric:", "").strip()
        elif (len(content) >= 6):
            des1 = content[3].text.strip()
            des2 = content[1].text.strip()
            detail = content[4].text.strip()
            z = content[5].text.find("Fabric")
            color = content[5].text[:z].replace("Color:", "").strip()
            fabric = content[5].text[z:].replace("Fabric:", "").strip()

        else:
            content = content[0]
            des1 = content.strong.text.strip()
            content = content.text
            z = content.find("Details:")
            l = content.find("Color")
            k = content.find("Fabric")
            j = content.find("SIZE")
            des2 = content[len(des1):z].strip()
            detail = content[z:l].replace("Details:", "").strip()
            color = content[l:k].replace("Color:", "").strip()
            fabric = content[k:j].replace("Fabric:", "").strip()


        prices = product_soup.find("div",{"class":"prices"})('span')
        oldprice = prices[1].text.strip()
        newprice = prices[2].text.strip()
        sizes = product_soup.find_all("div", {'class':'swatch-element'})
        all_sizes = []
        for size in sizes:
            all_sizes.append(size.label.text.strip())

        all_sizes = ','.join(all_sizes)
        #Images
        images = product_soup.find_all("a", {"class":"fancybox"})
        y = 0
        for a in images:
            file_name = str(x) + "." + str(y) + ".jpg"
            #print(a['href'] + file_name)
            y += 1
            urllib.request.urlretrieve("https:" + a['href'], file_name)
        
        x += 1
        row = {'Name':name,'Detail':detail,'Main-Description': des1,'Sub-Description':des2, 'Old-Price': oldprice, 'New-Price': newprice,'Color': color, 'Fabric' : fabric, 'All Sizes' : all_sizes,"Extra Detail" : extra_detail}
        all_rows.append(row)
    except:
        print(link)
        faultylinks.append(link)
        pass
#print(name, des1,des2,detail,color,fabric, oldprice, newprice, all_sizes,)
# Out:
# working...
# working...
# working...

# %%
len(faultylinks)
# Out:
# 2

# %%
products = pd.DataFrame(all_rows, columns = ['Name','Detail','Main-Description', 'Sub-Description','Old-Price','New-Price','Color', 'Fabric','All Sizes',"Extra Detail"])

# %%
#Scraping Products and Storing in DataFrame
products
# Out:
#                     Name                                             Detail  \
# 0        Army Camouflage  Plain Front, Plain Back, Full Sleeves, Band Ne...
# 1          Ashen Terrain  Plain Front, Plain Back, Full Sleeves, Band Ne...
# 2          Blooming Wave  Embroidered Front, Embroidered Back, Full Slee...
# 3           Blue Rampage  Printed Front, Printed Back, Full Sleeves, Ban...
# 4          Bohemian Lore  Embroidered Front, Plain Back, Full Sleeves wi...
# 5             Denim Blue  Plain Front, Plain Back, Full Sleeves, V Neckl...
# 6            Dream Spark  Plain Front with Embroidered Neck motif, Plain...
# 7          Florence Pink  Embroidered Front, Embroidered Back, Full Slee...
# 8              Gem Stone  Plain Front with Embroidered Neckline, Plain B...
# 9                Glaucus  Plain Front, Plain Back, Full Sleeves, Band Ne...
# 10           Ivory Mahal  Paste Printed Front, Paste Printed Back, Full ...
# 11        Light of Pearl  Embroidered Front, Plain Back with Embroidered...
# 12         Limitless Sky  Plain Front, Plain Back, Full Sleeves, Band Ne...
# 13        Magnolia White  Embroidered Front, Embroidered Back, Full Slee...
# 14           Mint Breeze  Embroidered Front, Embroidered Back, Full Slee...
# 15           Pastel Beam  Embroidered Front, Plain Back, Full Sleeves, Y...
# 16          Pastel Peace  Embroidered Front, Plain Back, Full Sleeves, R...
# 17            Pastel Rum  Embroidered Front, Embroidered Back, Full Slee...
# 18     Pistachio Florals  Embroidered Front, Embroidered Back, Full Slee...
# 19          Royal Boxers  Embroidered Front, Plain Back, Full Sleeves, B...
# 20       Blackish Galaxy
# 21              Red Wood  Embroidered Front, Plain Back, Full with Embro...
# 22           Green Fobia  Embroidered Front, Plain Back with Embroidered...
# 23         Mustard Mania  Embroidered Front, Embroidered Back, Full with...
# 24              Ice Pink  Embroidered Front, Plain Back, Full with Embro...
# 25     Glimmering Garden  Embroidered Front, Embroidered Back, Full with...
# 26           Black Frost
# 27        Stone age Glow
# 28          Glowing Star
# 29               Belgian
# ...                  ...                                                ...
# 1670           Magentine
# 1671           Esmerelda
# 1672             Moonlit
# 1673        Poppy Fields
# 1674              Senora
# 1675              Rosita
# 1676         Ivory Holly
# 1677         Star Seeker
# 1678     Cherry Blossoms
# 1679           Bluebelle
# 1680            Rose Dew
# 1681    Forest Gathering
# 1682       Flora Delight
# 1683          Rouge Noir
# 1684        Lilac Dreams
# 1685     Midnight Garden
# 1686          Taupe Rose
# 1687    Opulent Lavender
# 1688             Lantana
# 1689       Luxury Blooms
# 1690         Taupe Rouge
# 1691        Pink Cascade
# 1692           Rose Noir
# 1693  Monochrome Blossom
# 1694     Oriental Garden
# 1695       Rouge Bouquet
# 1696        Spring Calls
# 1697           Blue Lily
# 1698           Silk Rose
# 1699      Layered Blooms
#
#                    Main-Description  \
# 0                    Straight Kurta
# 1                  Front Open Shirt
# 2                    Straight Kurta
# 3     Straight Shirt with Round Hem
# 4                  Front Slit Shirt
# 5     Straight Shirt with Round Hem
# 6                    Straight Kurta
# 7                          Angrakha
# 8                    Straight Kurta
# 9                    Straight Kurta
# 10                   Straight Kurta
# 11                   Straight Kurta
# 12                   Straight Kurta
# 13                   Straight Kurta
# 14                   Straight Kurta
# 15                   Straight Kurta
# 16                   Straight Kurta
# 17                   Straight Kurta
# 18                   Straight Kurta
# 19                   Straight Kurta
# 20                    Tulip Shalwar
# 21                   Straight Kurta
# 22                 Front Slit Shirt
# 23                   Straight Kurta
# 24                         Angrakha
# 25                   Straight Kurta
# 26                   Straight Pants
# 27                    Tulip Shalwar
# 28                  Cigarette Pants
# 29                  Cigarette Pants
# ...                             ...
# 1670              Embroidered Ponch
# 1671              Embroidered Ponch
# 1672              Embroidered Ponch
# 1673              Embroidered Ponch
# 1674              Embroidered Ponch
# 1675              Embroidered Ponch
# 1676              Embroidered Ponch
# 1677              Embroidered Ponch
# 1678              Embroidered Ponch
# 1679              Embroidered Kimon
# 1680               Embroidered Shaw
# 1681               Embroidered Shaw
# 1682               Embroidered Shaw
# 1683               Embroidered Shaw
# 1684               Embroidered Shaw
# 1685               Embroidered Shaw
# 1686               Embroidered Shaw
# 1687               Embroidered Shaw
# 1688               Embroidered Shaw
# 1689               Embroidered Shaw
# 1690               Embroidered Shaw
# 1691               Embroidered Shaw
# 1692               Embroidered Shaw
# 1693               Embroidered Shaw
# 1694               Embroidered Shaw
# 1695               Embroidered Shaw
# 1696               Embroidered Shaw
# 1697               Embroidered Shaw
# 1698               Embroidered Shaw
# 1699               Embroidered Shaw
#
#                                         Sub-Description     Old-Price  \
# 0     This grey-blue denim shirt takes its inspirati...   Rs.3,490.00
# 1     This solid slate-grey linen shirt is minimal a...   Rs.3,990.00
# 2     This intricately embroidered cotton candy pink...   Rs.4,990.00
# 3     This versatile short shirt has a classic band ...   Rs.2,790.00
# 4     This lush lemon-yellow self-jacquard piece has...   Rs.3,490.00
# 5     This fashion-forward kurta is made from blue d...   Rs.3,490.00
# 6     The embroidered motif on the Y-neckline of thi...   Rs.3,990.00
# 7     This soft peach-pink angrakha has a white tass...   Rs.6,990.00
# 8     This organza jacquard confection is a vibrant ...   Rs.7,990.00
# 9     This East-meets-West piece combines slate-blue...   Rs.2,790.00
# 10    The classic ivory and gold combination of this...   Rs.5,490.00
# 11    This pure white kurta in delicate cotton net h...   Rs.3,990.00
# 12    A vibrant sky blue kurta with a band collar, m...   Rs.2,990.00
# 13    This elegant chikan kari kurta in pure white i...   Rs.3,990.00
# 14    This versatile band-collared shirt comes in a ...   Rs.4,990.00
# 15    This kurta is made from a light pistachio-hued...   Rs.6,490.00
# 16    This silky cotton net kurta comes in the light...   Rs.6,990.00
# 17    This heavily embroidered shirt comes in a refr...   Rs.4,990.00
# 18    A classic kurta with a Y-neckline and self emb...   Rs.4,990.00
# 19    Featuring a split band collar and intricately ...   Rs.5,990.00
# 20    This silky tulip shalwar comes in a jet-black ...   Rs.3,490.00
# 21    This longline kurta with a boat neck comes in ...   Rs.4,990.00
# 22    This deep teal crepe piece is the opposite of ...   Rs.6,990.00
# 23    This jacquard kurta with a Y-neckline comes in...   Rs.4,490.00
# 24    A delicate sea green khaddar angrakha, with an...   Rs.3,990.00
# 25    Geometric crimson motifs and cuff detailing ad...   Rs.4,990.00
# 26    These straight-cut trousers come in jet black ...   Rs.4,490.00
# 27    An elegant white tulip shalwar in raw silk wit...   Rs.3,990.00
# 28    These black cigarette pants in raw silk are be...   Rs.4,490.00
# 29    Raw silk cigarette trousers in a cream hue wit...   Rs.3,990.00
# ...                                                 ...           ...
# 1670                                                  o   Rs.8,490.00
# 1671                                                  o   Rs.8,490.00
# 1672                                                  o   Rs.8,490.00
# 1673                                                  o   Rs.8,490.00
# 1674                                                  o   Rs.8,490.00
# 1675                                                  o   Rs.8,490.00
# 1676                                                  o   Rs.8,490.00
# 1677                                                  o   Rs.8,490.00
# 1678                                                  o   Rs.8,490.00
# 1679                                                  o  Rs.24,990.00
# 1680                                                  l  Rs.34,990.00
# 1681                                                  l  Rs.34,990.00
# 1682                                                  l  Rs.34,990.00
# 1683                                                  l  Rs.34,990.00
# 1684                                                  l  Rs.24,990.00
# 1685                                                  l  Rs.24,990.00
# 1686                                                  l  Rs.34,990.00
# 1687                                                  l  Rs.34,990.00
# 1688                                                  l  Rs.34,990.00
# 1689                                                  l  Rs.34,990.00
# 1690                                                  l  Rs.24,990.00
# 1691                                                  l  Rs.29,990.00
# 1692                                                  l  Rs.34,990.00
# 1693                                                  l  Rs.29,990.00
# 1694                                                  l  Rs.34,990.00
# 1695                                                  l  Rs.24,990.00
# 1696                                                  l  Rs.24,990.00
# 1697                                                  l  Rs.24,990.00
# 1698                                                  l  Rs.34,990.00
# 1699                                                  l  Rs.34,990.00
#
#          New-Price              Color               Fabric        All Sizes  \
# 0      Rs.2,268.50               Blue                Denim      XS,S,M,L,XL
# 1      Rs.1,995.00         Light Grey                Lilen      XS,S,M,L,XL
# 2      Rs.3,243.50               Pink             Shifflee      XS,S,M,L,XL
# 3      Rs.1,813.50               Blue                Denim      XS,S,M,L,XL
# 4      Rs.2,268.50             Yellow        Self Jacquard  XXS,XS,S,M,L,XL
# 5      Rs.2,268.50               Blue                Denim      XS,S,M,L,XL
# 6      Rs.2,593.50               Pink               Cotton      XS,S,M,L,XL
# 7      Rs.4,543.50              Peach             Shifflee      XS,S,M,L,XL
# 8      Rs.5,193.50            Emerald     Organza Jacquard      XS,S,M,L,XL
# 9      Rs.1,813.50               Grey                Denim      XS,S,M,L,XL
# 10     Rs.3,568.50              Ivory             Raw Silk  XXS,XS,S,M,L,XL
# 11     Rs.2,593.50              White           Cotton Net      XS,S,M,L,XL
# 12     Rs.1,943.50           Sky Blue                Denim      XS,S,M,L,XL
# 13     Rs.2,593.50              White             Shifflee      XS,S,M,L,XL
# 14     Rs.3,243.50         Mint Green             Shifflee  XXS,XS,S,M,L,XL
# 15     Rs.4,218.50  Green / Pistachio      Silk Cotton Net      XS,S,M,L,XL
# 16     Rs.4,543.50    Pastel Tea Pink      Silk Cotton Net      XS,S,M,L,XL
# 17     Rs.3,243.50             Yellow             Shifflee      XS,S,M,L,XL
# 18     Rs.3,243.50         Mint Green             Shifflee      XS,S,M,L,XL
# 19     Rs.3,893.50              White  Yarn Dyed Dobby Box      XS,S,M,L,XL
# 20     Rs.2,268.50              Black         Bemberg Grip  XXS,XS,S,M,L,XL
# 21     Rs.3,243.50                Red        Self Jacquard  XXS,XS,S,M,L,XL
# 22     Rs.4,543.50              Green         Crepe Weaved      XS,S,M,L,XL
# 23     Rs.2,918.50            Mustard        Self Jacquard      XS,S,M,L,XL
# 24     Rs.2,593.50          Sea Green              Khaddar  XXS,XS,S,M,L,XL
# 25     Rs.3,243.50          Off-White        Self Jacquard  XXS,XS,S,M,L,XL
# 26     Rs.2,918.50              Black             Raw Silk      XS,S,M,L,XL
# 27     Rs.2,593.50              White             Raw Silk  XXS,XS,S,M,L,XL
# 28     Rs.2,918.50              Black             Raw Silk  XXS,XS,S,M,L,XL
# 29     Rs.2,593.50              Cream             Raw Silk  XXS,XS,S,M,L,XL
# ...            ...                ...                  ...              ...
# 1670   Rs.4,245.00              Black               Velvet
# 1671   Rs.4,245.00              Black               Velvet
# 1672   Rs.4,245.00              Black               Velvet
# 1673   Rs.4,245.00              Black               Velvet
# 1674   Rs.4,245.00              Black               Velvet
# 1675   Rs.4,245.00              Black               Velvet
# 1676   Rs.4,245.00              Black               Velvet
# 1677   Rs.4,245.00              Black               Velvet
# 1678   Rs.4,245.00              Black               Velvet
# 1679  Rs.12,495.00              White                  Net
# 1680  Rs.17,495.00              White      Poly satin Silk
# 1681  Rs.17,495.00              Black               Velvet
# 1682  Rs.17,495.00             Maroon               Velvet
# 1683  Rs.17,495.00              Black               Velvet
# 1684  Rs.12,495.00              Black               Velvet
# 1685  Rs.12,495.00               Blue               Velvet
# 1686  Rs.17,495.00           Tea Pink               Velvet
# 1687  Rs.17,495.00              Black               Velvet
# 1688  Rs.17,495.00             Maroon               Velvet
# 1689  Rs.17,495.00              Black               Velvet
# 1690  Rs.12,495.00           Tea Pink               Velvet
# 1691  Rs.14,995.00              Black               Velvet
# 1692  Rs.17,495.00              Black               Velvet
# 1693  Rs.14,995.00              Black               Velvet
# 1694  Rs.17,495.00              Black               Velvet
# 1695  Rs.12,495.00              Black               Velvet
# 1696  Rs.12,495.00              Black               Velvet
# 1697  Rs.12,495.00               Blue               Velvet
# 1698  Rs.17,495.00              Black      Poly satin Silk
# 1699  Rs.17,495.00              Black               Velvet
#
#      Extra Detail
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# 5            None
# 6            None
# 7            None
# 8            None
# 9            None
# 10           None
# 11           None
# 12           None
# 13           None
# 14           None
# 15           None
# 16           None
# 17           None
# 18           None
# 19           None
# 20           None
# 21           None
# 22           None
# 23           None
# 24           None
# 25           None
# 26           None
# 27           None
# 28           None
# 29           None
# ...           ...
# 1670         None
# 1671         None
# 1672         None
# 1673         None
# 1674         None
# 1675         None
# 1676         None
# 1677         None
# 1678         None
# 1679         None
# 1680         None
# 1681         None
# 1682         None
# 1683         None
# 1684         None
# 1685         None
# 1686         None
# 1687         None
# 1688         None
# 1689         None
# 1690         None
# 1691         None
# 1692         None
# 1693         None
# 1694         None
# 1695         None
# 1696         None
# 1697         None
# 1698         None
# 1699         None
#
# [1700 rows x 10 columns]

# %%
products.to_csv('Sapphire-ReadyToWear.csv', encoding='utf-8')
